# %% [markdown]
# This workbook takes the technology csv prepared by AEMDA and fills in any missing values based on the TEAM version.

# %%
import pandas as pd

# %%
# import technology - team kenya complete set
tk_tech = pd.read_excel(f'./sample_data/team_kenya_technology.xlsx')
tk_tech
# Out:
#       TechID  ModeID  VehTypeID  MassCatID  FuelID  EngineID  TransTypeID  \
# 0         10       1          2          4       1        10            1
# 1         20       1          2          4      12        10            1
# 2         25       1          2          4      12        11            1
# 3         26       1          2          4      12        12            1
# 4         30       1          2          4       1        11            1
# ...      ...     ...        ...        ...     ...       ...          ...
# 2241   14889       1          5         28      13        13            2
# 2242   14890       1          5         28      13        13            2
# 2243   14891       1          5         28      13        13            2
# 2244   14892       1          5         28      13        13            2
# 2245   14893       1          5         28      13        13            2
#
#       Availability  Final_Year  HybridFlag  spec_energ_consump  \
# ...

# %%
# import technology - aemda set
aemda_tech = pd.read_csv(f'./out_data/Technology.csv')
aemda_tech
# Out:
#      TechID  ModeID  VehTypeID  MassCatID  FuelID  EngineID  TransTypeID  \
# 0        70       1          3          1       1         1            1
# 1      9070       1          3          1       1         1            1
# 2        90       1          3          1       1         3            1
# 3      9090       1          3          1       1         3            1
# 4       100       1          3          1       1         4            1
# ..      ...     ...        ...        ...     ...       ...          ...
# 273   14801       1          2          4       1         4            1
# 274    5802       1          2          4       1         5            1
# 275   14802       1          2          4       1         5            1
# 276    5603       1          2          4       1         6            1
# 277   14803       1          2          4       1         6            1
#
#      Availability  Final_Year  HybridFlag  spec_energ_consump  \
# ...

# %%
# tk_tech.loc[tk_tech[tk_tech.TechID == 70].index.item()]

# %%
# aemda_tech.loc[aemda_tech[aemda_tech.TechID == 70].index.item()]

# %%
# aemda_tech.loc[aemda_tech[aemda_tech.TechID == 70].index.item()] = tk_tech.loc[tk_tech[tk_tech.TechID == 70].index.item()]

# %%
# aemda_tech.loc[aemda_tech[aemda_tech.TechID == 70].index.item()]

# %%
for TechID in aemda_tech.TechID.unique():
    aemda_tech.loc[aemda_tech[aemda_tech.TechID == TechID].index.item()] = tk_tech.loc[tk_tech[tk_tech.TechID == TechID].index.item()]

aemda_tech
# Out:
#      TechID  ModeID  VehTypeID  MassCatID  FuelID  EngineID  TransTypeID  \
# 0        70       1          3          1       1         1            1
# 1      9070       1          3          1       1         1            1
# 2        90       1          3          1       1         3            1
# 3      9090       1          3          1       1         3            1
# 4       100       1          3          1       1         4            1
# ..      ...     ...        ...        ...     ...       ...          ...
# 273   14801       1          5         28       1         4            2
# 274    5802       1          5         28       1         5            2
# 275   14802       1          5         28       1         5            2
# 276    5603       1          5         27       1         6            2
# 277   14803       1          5         28       1         6            2
#
#      Availability  Final_Year  HybridFlag  spec_energ_consump  \
# ...

# %%
aemda_tech.to_csv('./out_data/aemda_technology.csv')
