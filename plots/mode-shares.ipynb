# %% [markdown]
# This notebook plots mode shift data, but problem is that fuck knows how to get that as data is a mess. first off try vehicle-km / load factor...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
# import technology data
technology = pd.read_csv(f'./../data/technology.csv')
technology
# Out:
#       TechID  ModeID  VehTypeID  MassCatID  FuelID  EngineID  TransTypeID  \
# 0         10       1          2          4       1        10            1
# 1         20       1          2          4      12        10            1
# 2         25       1          2          4      12        11            1
# 3         26       1          2          4      12        12            1
# 4         30       1          2          4       1        11            1
# ...      ...     ...        ...        ...     ...       ...          ...
# 2241   14889       1          5         28      13        13            2
# 2242   14890       1          5         28      13        13            2
# 2243   14891       1          5         28      13        13            2
# 2244   14892       1          5         28      13        13            2
# 2245   14893       1          5         28      13        13            2
#
#       Availability  Final_Year  HybridFlag  spec_energ_consump  \
# ...

# %%
# import vehicle-km data
scenario = 'OMOKA'
vkm = pd.read_excel(f'./../scenarios/data-out/{scenario}/Interface_VSM_VehKM.xlsx')
vkm
# Out:
#        TDVSID  ScenarioID  CountryID  Year  TechID  JSTypeID         VehKM  \
# 0           0           1          9  2012      10         1  3.101124e+09
# 1           0           1          9  2012      10         2  2.263109e+09
# 2           0           1          9  2012      10         3  4.303590e+08
# 3           0           1          9  2012      25         1  2.440549e+08
# 4           0           1          9  2012      25         2  1.781041e+08
# ...       ...         ...        ...   ...     ...       ...           ...
# 92161       0           1          9  2050   14891         2  7.578651e+06
# 92162       0           1          9  2050   14891         3  3.598806e+06
# 92163       0           1          9  2050   14892         1  4.276496e+06
# 92164       0           1          9  2050   14892         2  4.488092e+06
# 92165       0           1          9  2050   14892         3  2.131220e+06
#
#        AveTripLength  LoadFactor
# 0           10.45850    0.500000
# ...

# %%
# compute pkm based on vkm, capacity and load factor
vkm['PKM'] = 0

for i in list(vkm.index.values):
    
    if i%100 == 0:
        print(i)
    
    # compute avg occupancy
    AvgOccupancy = technology[technology.TechID == vkm.TechID[i]].Capacity.item() * vkm.LoadFactor[i]
    
    # compute pkm
    vkm.at[i, 'PKM'] = vkm.VehKM[i] * AvgOccupancy
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
# create total pkm vectors by year and mode
chart_data = []
for vehtype in [2, 3, 4]:
    vehtype_vector = []
    for year in range(2015, 2051):
        pkm = vkm[(vkm.TechID.isin(technology[technology.VehTypeID == vehtype].TechID.tolist())) & (vkm.Year == year)].PKM.sum()
        vehtype_vector.append(pkm)
    chart_data.append(vehtype_vector)

# %%
fig, ax = plt.subplots()
ax.stackplot(range(2015, 2051), chart_data, colors=sns.color_palette('colorblind'), labels=['Moto', 'Car', 'Bus'])
ax.set_ylabel('pkm')
ax.set_xlim(left=2015, right=2050)

ax.set_title(scenario)
ax.legend()

fig.tight_layout()
plt.savefig(f'mode-shares-from-vkm-{scenario}.pdf')
