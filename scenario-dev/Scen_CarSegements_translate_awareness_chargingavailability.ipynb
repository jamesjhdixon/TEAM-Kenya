# %% [markdown]
# This workbook translates scenarios for shAwareEV, shPAccessToOC, shFCertaintyOfAccess and saves them to a version of scen_car_segments

# %%
import pandas as pd

# %%
def return_technology():
    technology = pd.read_excel(f'./../TEAM-Kenya_data_out/original-team-uk-data/Technology.xlsx')
    return technology

# %%
# return scen_carsegments
def return_scen_carsegments():
    scen_carsegments = pd.read_excel(f'./../TEAM-Kenya_data_out/original-team-uk-data/Scen_CarSegments.xlsx')
    return scen_carsegments

# %%
scenario_dict = {'OMOKA': {'shAwareEV': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.15,
 2022: 0.18,
 2023: 0.26,
 2024: 0.35,
 2025: 0.45,
 2026: 0.55,
 2027: 0.60,
 2028: 0.65,
 2029: 0.69,
 2030: 0.72,
 2031: 0.78,
 2032: 0.84,
 2033: 0.91,
 2034: 0.95,
 2035: 1,
 2036: 1,
 2037: 1,
 2038: 1,
 2039: 1,
 2040: 1,
 2041: 1,
 2042: 1,
 2043: 1,
 2044: 1,
 2045: 1,
 2046: 1,
 2047: 1,
 2048: 1,
 2049: 1,
 2050: 1},
 'shPAccessToOC': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.15,
 2022: 0.18,
 2023: 0.26,
 2024: 0.35,
 2025: 0.45,
 2026: 0.55,
 2027: 0.60,
 2028: 0.65,
 2029: 0.69,
 2030: 0.72,
 2031: 0.78,
 2032: 0.84,
 2033: 0.91,
 2034: 0.95,
 2035: 1,
 2036: 1,
 2037: 1,
 2038: 1,
 2039: 1,
 2040: 1,
 2041: 1,
 2042: 1,
 2043: 1,
 2044: 1,
 2045: 1,
 2046: 1,
 2047: 1,
 2048: 1,
 2049: 1,
 2050: 1},
 'shFCertaintyOfAccess': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.15,
 2022: 0.18,
 2023: 0.26,
 2024: 0.35,
 2025: 0.45,
 2026: 0.55,
 2027: 0.60,
 2028: 0.65,
 2029: 0.69,
 2030: 0.72,
 2031: 0.78,
 2032: 0.84,
 2033: 0.91,
 2034: 0.95,
 2035: 1,
 2036: 1,
 2037: 1,
 2038: 1,
 2039: 1,
 2040: 1,
 2041: 1,
 2042: 1,
 2043: 1,
 2044: 1,
 2045: 1,
 2046: 1,
 2047: 1,
 2048: 1,
 2049: 1,
 2050: 1}},
'ELECTRICDREAMS': {'shAwareEV': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.15,
 2022: 0.18,
 2023: 0.26,
 2024: 0.35,
 2025: 0.45,
 2026: 0.49,
 2027: 0.60,
 2028: 0.80,
 2029: 0.91,
 2030: 1,
 2031: 1,
 2032: 1,
 2033: 1,
 2034: 1,
 2035: 1,
 2036: 1,
 2037: 1,
 2038: 1,
 2039: 1,
 2040: 1,
 2041: 1,
 2042: 1,
 2043: 1,
 2044: 1,
 2045: 1,
 2046: 1,
 2047: 1,
 2048: 1,
 2049: 1,
 2050: 1},
 'shPAccessToOC': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.15,
 2022: 0.18,
 2023: 0.26,
 2024: 0.35,
 2025: 0.45,
 2026: 0.49,
 2027: 0.60,
 2028: 0.80,
 2029: 0.91,
 2030: 1,
 2031: 1,
 2032: 1,
 2033: 1,
 2034: 1,
 2035: 1,
 2036: 1,
 2037: 1,
 2038: 1,
 2039: 1,
 2040: 1,
 2041: 1,
 2042: 1,
 2043: 1,
 2044: 1,
 2045: 1,
 2046: 1,
 2047: 1,
 2048: 1,
 2049: 1,
 2050: 1},
 'shFCertaintyOfAccess': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.15,
 2022: 0.18,
 2023: 0.26,
 2024: 0.35,
 2025: 0.45,
 2026: 0.49,
 2027: 0.60,
 2028: 0.80,
 2029: 0.91,
 2030: 1,
 2031: 1,
 2032: 1,
 2033: 1,
 2034: 1,
 2035: 1,
 2036: 1,
 2037: 1,
 2038: 1,
 2039: 1,
 2040: 1,
 2041: 1,
 2042: 1,
 2043: 1,
 2044: 1,
 2045: 1,
 2046: 1,
 2047: 1,
 2048: 1,
 2049: 1,
 2050: 1}},
'KUJINAO': {'shAwareEV':  {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.09,
 2022: 0.12,
 2023: 0.18,
 2024: 0.24,
 2025: 0.28,
 2026: 0.35,
 2027: 0.42,
 2028: 0.51,
 2029: 0.56,
 2030: 0.6,
 2031: 0.62,
 2032: 0.67,
 2033: 0.7,
 2034: 0.72,
 2035: 0.75,
 2036: 0.75,
 2037: 0.75,
 2038: 0.75,
 2039: 0.75,
 2040: 0.75,
 2041: 0.75,
 2042: 0.75,
 2043: 0.75,
 2044: 0.75,
 2045: 0.75,
 2046: 0.75,
 2047: 0.75,
 2048: 0.75,
 2049: 0.75,
 2050: 0.75},
 'shPAccessToOC':  {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.09,
 2022: 0.12,
 2023: 0.13,
 2024: 0.14,
 2025: 0.18,
 2026: 0.23,
 2027: 0.28,
 2028: 0.3,
 2029: 0.32,
 2030: 0.34,
 2031: 0.38,
 2032: 0.42,
 2033: 0.46,
 2034: 0.49,
 2035: 0.52,
 2036: 0.55,
 2037: 0.59,
 2038: 0.62,
 2039: 0.65,
 2040: 0.7,
 2041: 0.72,
 2042: 0.75,
 2043: 0.75,
 2044: 0.75,
 2045: 0.75,
 2046: 0.75,
 2047: 0.75,
 2048: 0.75,
 2049: 0.75,
 2050: 0.75},
 'shFCertaintyOfAccess': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.09,
 2022: 0.12,
 2023: 0.13,
 2024: 0.14,
 2025: 0.18,
 2026: 0.23,
 2027: 0.28,
 2028: 0.33,
 2029: 0.38,
 2030: 0.42,
 2031: 0.44,
 2032: 0.46,
 2033: 0.49,
 2034: 0.52,
 2035: 0.55,
 2036: 0.58,
 2037: 0.62,
 2038: 0.65,
 2039: 0.69,
 2040: 0.72,
 2041: 0.75,
 2042: 0.75,
 2043: 0.75,
 2044: 0.75,
 2045: 0.75,
 2046: 0.75,
 2047: 0.75,
 2048: 0.75,
 2049: 0.75,
 2050: 0.75}},
'STREETFIGHTING': {'shAwareEV': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.09,
 2022: 0.12,
 2023: 0.13,
 2024: 0.14,
 2025: 0.18,
 2026: 0.23,
 2027: 0.28,
 2028: 0.33,
 2029: 0.38,
 2030: 0.42,
 2031: 0.44,
 2032: 0.46,
 2033: 0.49,
 2034: 0.52,
 2035: 0.55,
 2036: 0.55,
 2037: 0.55,
 2038: 0.55,
 2039: 0.55,
 2040: 0.55,
 2041: 0.55,
 2042: 0.55,
 2043: 0.55,
 2044: 0.55,
 2045: 0.55,
 2046: 0.55,
 2047: 0.55,
 2048: 0.55,
 2049: 0.55,
 2050: 0.55},
 'shPAccessToOC': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.09,
 2022: 0.12,
 2023: 0.13,
 2024: 0.14,
 2025: 0.18,
 2026: 0.23,
 2027: 0.28,
 2028: 0.33,
 2029: 0.38,
 2030: 0.42,
 2031: 0.44,
 2032: 0.46,
 2033: 0.49,
 2034: 0.52,
 2035: 0.55,
 2036: 0.55,
 2037: 0.55,
 2038: 0.55,
 2039: 0.55,
 2040: 0.55,
 2041: 0.55,
 2042: 0.55,
 2043: 0.55,
 2044: 0.55,
 2045: 0.55,
 2046: 0.55,
 2047: 0.55,
 2048: 0.55,
 2049: 0.55,
 2050: 0.55},
 'shFCertaintyOfAccess': {2012: 0.05,
 2013: 0.05,
 2014: 0.05,
 2015: 0.05,
 2016: 0.05,
 2017: 0.05,
 2018: 0.05,
 2019: 0.05,
 2020: 0.07,
 2021: 0.09,
 2022: 0.12,
 2023: 0.13,
 2024: 0.14,
 2025: 0.18,
 2026: 0.23,
 2027: 0.28,
 2028: 0.33,
 2029: 0.38,
 2030: 0.42,
 2031: 0.44,
 2032: 0.46,
 2033: 0.49,
 2034: 0.52,
 2035: 0.55,
 2036: 0.55,
 2037: 0.55,
 2038: 0.55,
 2039: 0.55,
 2040: 0.55,
 2041: 0.55,
 2042: 0.55,
 2043: 0.55,
 2044: 0.55,
 2045: 0.55,
 2046: 0.55,
 2047: 0.55,
 2048: 0.55,
 2049: 0.55,
 2050: 0.55}}}

# %%
import numpy as np
scenarios = ['OMOKA', 'ELECTRICDREAMS', 'KUJINAO', 'STREETFIGHTING']

for scenario in scenarios:

    scen_carsegments = return_scen_carsegments()

    for year in range(2012, 2051):

        set_ind = scen_carsegments[scen_carsegments.Year == year].index.tolist()

        for var in scenario_dict[scenario]:

            scen_carsegments.loc[set_ind, var] = np.round(scenario_dict[scenario][var][year],2)

    # save
    scen_carsegments.to_excel(f'./../TEAM-Kenya_data_out/scenarios/Scen_CarSegments{scenario}.xlsx', index=False)
